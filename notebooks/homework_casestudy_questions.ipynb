# %% [markdown]
# # Case Study Overview
#
# Retail organizations generate thousands of sales transactions every day. Analyzing these transactions helps businesses understand customer behavior, evaluate store performance, identify sales trends, and make informed business decisions.
#
# In this case study, MongoDB is used as the primary data source for performing **Exploratory Data Analysis (EDA)**. Using **PyMongo**, we will query the sales data, analyze key business metrics, and visualize the results to gain meaningful business insights.
#
# This notebook demonstrates a typical data analysis workflow using MongoDB and serves as a sample EDA case study. Students can use the same methodology to analyze different MongoDB datasets in future assignments.

# %% [markdown]
# # Business Objectives
#
# The primary objectives of this case study are to:
#
# - Understand the structure of the MongoDB dataset.
# - Explore the sales transaction data using PyMongo.
# - Perform exploratory data analysis (EDA) on business data.
# - Answer business questions using MongoDB queries.
# - Visualize analytical results using Python.
# - Interpret the findings and derive meaningful business insights.
# - Provide actionable recommendations based on the analysis.

# %% [markdown]
# # Case Study Workflow
#
# The case study follows the standard Exploratory Data Analysis (EDA) workflow used in data analytics projects.
#
# 1. Environment Setup
# 2. Understand the Dataset
# 3. Perform Exploratory Data Analysis
# 4. Visualize Results
# 5. Generate Business Insights
# 6. Provide Actionable Recommendations
#
# By following this workflow, raw business data is transformed into meaningful information that supports effective decision-making.

# %% [markdown]
# # Environment Setup
#
# Before starting the exploratory data analysis, we need to prepare the Python environment and establish a connection with the local MongoDB Community Server.
#
# This section imports the required Python libraries, configures the notebook for better readability, and connects to the MongoDB database containing the business dataset.

# %% [markdown]
# ## Import Required Libraries
#
# The following libraries are used throughout this case study:
#
# - **PyMongo** – Connect to MongoDB and execute queries.
# - **Pandas** – Data manipulation and tabular analysis.
# - **NumPy** – Numerical operations.
# - **Matplotlib** – Data visualization.
# - **Seaborn** – Statistical data visualization.
# - **pprint** – Display MongoDB documents in a readable format.

# %%
from pymongo import MongoClient

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pprint import pprint

# %% [markdown]
# ## Configure Notebook Settings
#
# Configure display options to improve the readability of tables and visualizations throughout the notebook.

# %%
# Pandas Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# Visualization Settings
plt.style.use("ggplot")
sns.set_theme(style="whitegrid")

plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["figure.dpi"] = 120

# %% [markdown]
# ## Connect to MongoDB
#
# Create a connection to the local MongoDB Community Server.

# %%
client = MongoClient("mongodb://localhost:27017")

# %% [markdown]
# # Dataset Setup
#
# Before starting this case study, the **sample_supplies** dataset must be imported into your local MongoDB Community Server.
#
# This is a one-time setup process. Once imported, the dataset remains available in your local MongoDB instance until it is deleted.

# %% [markdown]
# ## Step 1: Download the Dataset
#
# The dataset used in this case study is available from the following GitHub repository:
#
# https://github.com/neelabalan/mongodb-sample-dataset
#
# Download or clone the repository and locate the following file:
#
# ```
#
# mongodb-sample-dataset/
# └── sample_supplies/
#     └── sales.json
#
# ```
#
# This file contains the sales transaction data used throughout this notebook.

# %% [markdown]
# ## Step 2: Import the Dataset into MongoDB
#
# Open **Command Prompt** or **PowerShell** and execute the following command.
#
# Replace the file path with the location of **sales.json** on your computer.

# %%
# !mongoimport --db sample_supplies --collection sales --file "C:\path\to\sales.json"

# %% [markdown]
# If the import is successful, MongoDB will create:
#
# - **Database:** `sample_supplies`
# - **Collection:** `sales`
#
# The dataset is now ready for analysis using PyMongo.

# %% [markdown]
# ## Connect to the Database and Collection
#
# Connect to the **sample_supplies** database and access the **sales** collection, which will be used throughout this case study.

# %%
db = client["sample_supplies"]

sales = db["sales"]

# %% [markdown]
# ## Verify the Connection
#
# Before beginning the analysis, verify that the collection is accessible and contains data.

# %%
print(f"Database   : {db.name}")
print(f"Collection : {sales.name}")
print(f"Documents  : {sales.count_documents({}):,}")
# Out:
# Database   : sample_supplies
# Collection : sales
# Documents  : 5,000

# %% [markdown]
# # Question 1: What is the total number of sales transactions recorded in the dataset?

# %% [markdown]
# ## Business Objective
#
# Management wants to determine the total number of sales transactions recorded by the business. This metric provides an overview of the business activity and serves as a baseline Key Performance Indicator (KPI) for further analysis.

# %% [markdown]
# ## Code for Query

# %%
total_transactions = sales.count_documents({})

print(total_transactions)
# Out:
# 5000

# %% [markdown]
# ## Code for Visualization

# %%
plt.figure(figsize=(6, 4))

plt.bar(
    ["Total Transactions"],
    [total_transactions]
)

plt.title("Total Number of Sales Transactions")

plt.ylabel("Number of Transactions")

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# The dataset contains 5,000 sales transactions, indicating sufficient sales data for analyzing customer purchasing patterns, revenue performance, and operational trends.
# This transaction volume provides a reliable foundation for measuring key business KPIs and benchmarking future performance.

# %% [markdown]
# # Question 2: How many sales transactions were processed by each store location, and how do the transaction volumes compare across different store locations?

# %% [markdown]
# ## Business Objective
#
# Management wants to compare the number of sales transactions processed by each store location to identify stores with higher and lower customer activity. This analysis helps support resource allocation, inventory planning, and operational decision-making across different business locations.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$group": {
            "_id": "$storeLocation",
            "transactions": {
                "$sum": 1
            }
        }
    },
    {
        "$sort": {
            "transactions": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

store_transactions = pd.DataFrame(result)

store_transactions
# Out:
#          _id  transactions
# 0     Denver          1549
# 1    Seattle          1134
# 2     London           794
# 3     Austin           676
# 4   New York           501
# 5  San Diego           346

# %% [markdown]
# ## Code for Visualization

# %%
store_transactions.rename(
    columns={"_id": "Store Location"},
    inplace=True
)

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    data=store_transactions,
    x="Store Location",
    y="transactions"
)

plt.title("Sales Transactions by Store Location")

plt.xlabel("Store Location")

plt.ylabel("Number of Transactions")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Transaction volume varies across store locations, indicating differences in customer footfall and regional demand.Stores with higher transaction counts demonstrate stronger customer engagement, while lower-performing locations may require operational or marketing improvements

# %% [markdown]
# # Question 3: How many sales transactions were completed using each purchase method, and how do customers' purchasing preferences compare across different purchase methods?

# %% [markdown]
# ## Business Objective
#
# The company offers multiple purchase methods, such as **In-store**, **Online**, and **Phone**. Management wants to compare the number of sales transactions completed through each purchase method to understand customers' purchasing preferences. This analysis helps evaluate the popularity of different sales channels and supports decisions related to customer service, sales strategy, and resource allocation.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$group": {
            "_id": "$purchaseMethod",
            "transactions": {
                "$sum": 1
            }
        }
    },
    {
        "$sort": {
            "transactions": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

purchase_method_transactions = pd.DataFrame(result)

purchase_method_transactions
# Out:
#         _id  transactions
# 0  In store          2819
# 1    Online          1585
# 2     Phone           596

# %% [markdown]
# ## Code for Visualization

# %%
purchase_method_transactions.rename(
    columns={"_id": "Purchase Method"},
    inplace=True
)

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=purchase_method_transactions,
    x="Purchase Method",
    y="transactions"
)

plt.title("Sales Transactions by Purchase Method")

plt.xlabel("Purchase Method")

plt.ylabel("Number of Transactions")

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Customers use multiple purchase methods (In-store, Online, and Phone), showing the importance of maintaining an omnichannel sales strategy.The most frequently used purchase method represents customers' preferred shopping experience and contributes significantly to overall business activity.

# %% [markdown]
# # Question 4: How many sales transactions were completed using coupons, and how many were completed without using coupons?

# %% [markdown]
# ## Business Objective
#
# Management wants to evaluate customer adoption of promotional coupons by comparing the number of sales transactions completed using coupons with those completed without coupons.
#
# This analysis helps assess the effectiveness of coupon-based promotional campaigns and understand customers' purchasing behavior.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$group": {
            "_id": "$couponUsed",
            "transactions": {
                "$sum": 1
            }
        }
    },
    {
        "$sort": {
            "transactions": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

coupon_transactions = pd.DataFrame(result)

coupon_transactions
# Out:
#      _id  transactions
# 0  False          4523
# 1   True           477

# %% [markdown]
# ## Code for Visualization

# %%
coupon_transactions.rename(
    columns={"_id": "Coupon Used"},
    inplace=True
)

# %%
plt.figure(figsize=(7, 5))

sns.barplot(
    data=coupon_transactions,
    x="Coupon Used",
    y="transactions"
)

plt.title("Sales Transactions by Coupon Usage")

plt.xlabel("Coupon Used")

plt.ylabel("Number of Transactions")

plt.xticks(
    ticks=[0,1],
    labels=["No Coupon", "Coupon Used"]
)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# A comparison of coupon and non-coupon transactions highlights customer response to promotional campaigns.Coupon usage indicates that discounts influence purchasing behavior and can effectively drive additional sales.

# %% [markdown]
# # Question 5: How many sales transactions were recorded in each year?

# %% [markdown]
# ## Business Objective
#
# Management wants to compare the number of sales transactions recorded each year to understand how business activity has changed over time.
#
# Analyzing annual transaction volumes helps identify long-term business trends and supports strategic planning.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$group": {
            "_id": {
                "$year": "$saleDate"
            },
            "transactions": {
                "$sum": 1
            }
        }
    },
    {
        "$sort": {
            "_id": 1
        }
    }
]

result = list(sales.aggregate(pipeline))

yearly_transactions = pd.DataFrame(result)

yearly_transactions
# Out:
#     _id  transactions
# 0  2013           991
# 1  2014           941
# 2  2015          1006
# 3  2016          1010
# 4  2017          1052

# %% [markdown]
# ## Code for Visualization

# %%
yearly_transactions.rename(
    columns={"_id": "Year"},
    inplace=True
)

# %%
plt.figure(figsize=(8,5))

sns.lineplot(
    data=yearly_transactions,
    x="Year",
    y="transactions",
    marker="o"
)

plt.title("Year-wise Sales Transactions")

plt.xlabel("Year")

plt.ylabel("Number of Transactions")

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Sales transactions are distributed across multiple years, enabling year-over-year business performance analysis.Comparing yearly sales helps identify business growth, stability, or changes in customer demand over time.

# %% [markdown]
# # Question 6: How many sales transactions were recorded in each month, and are there any seasonal variations in transaction volume?

# %% [markdown]
# ## Business Objective
#
# Management wants to compare the number of sales transactions recorded in each month to identify seasonal variations in customer purchasing activity.
#
# Understanding monthly transaction patterns helps the business plan inventory levels, staffing requirements, and promotional campaigns during periods of high and low customer demand.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$group": {
            "_id": {
                "$month": "$saleDate"
            },
            "transactions": {
                "$sum": 1
            }
        }
    },
    {
        "$sort": {
            "_id": 1
        }
    }
]

result = list(sales.aggregate(pipeline))

monthly_transactions = pd.DataFrame(result)

monthly_transactions
# Out:
#     _id  transactions
# 0     1           444
# 1     2           359
# 2     3           419
# 3     4           394
# 4     5           426
# 5     6           418
# 6     7           437
# 7     8           414
# 8     9           389
# 9    10           444
# 10   11           423
# 11   12           433

# %% [markdown]
# ## Code for Visualization

# %%
import calendar

monthly_transactions["Month"] = monthly_transactions["_id"].apply(
    lambda x: calendar.month_name[x]
)

monthly_transactions
# Out:
#     _id  transactions      Month
# 0     1           444    January
# 1     2           359   February
# 2     3           419      March
# 3     4           394      April
# 4     5           426        May
# 5     6           418       June
# 6     7           437       July
# 7     8           414     August
# 8     9           389  September
# 9    10           444    October
# 10   11           423   November
# 11   12           433   December

# %%
plt.figure(figsize=(10,5))

sns.lineplot(
    data=monthly_transactions,
    x="Month",
    y="transactions",
    marker="o"
)

plt.title("Monthly Sales Transaction Trend")

plt.xlabel("Month")

plt.ylabel("Number of Transactions")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Monthly sales trends reveal seasonal fluctuations in customer purchasing behavior.
# Months with higher transaction volumes indicate peak business periods, while lower months highlight opportunities for promotional campaigns.

# %% [markdown]
# # Question 7: How many unique products are sold by the business, and what are their names?

# %% [markdown]
# ## Business Objective
#
# Management wants to identify the number of unique products offered by the business and obtain the complete list of products available for sale.
#
# Understanding the product portfolio helps the business evaluate product diversity, support inventory planning, and assist in future product management decisions.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$items.name"
        }
    },
    {
        "$sort": {
            "_id": 1
        }
    }
]

result = list(sales.aggregate(pipeline))

unique_products = pd.DataFrame(result)

unique_products
# Out:
#              _id
# 0       backpack
# 1         binder
# 2      envelopes
# 3         laptop
# 4        notepad
# 5           pens
# 6  printer paper

# %% [markdown]
# ## Code for Visualization

# %%
total_products = unique_products.shape[0]

print("Total Unique Products:", total_products)
# Out:
# Total Unique Products: 7

# %%
plt.figure(figsize=(5,4))

plt.bar(
    ["Unique Products"],
    [total_products]
)

plt.title("Total Number of Unique Products")

plt.ylabel("Count")

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# The business offers 7 unique products, reflecting a focused product portfolio.
# Understanding product diversity helps evaluate product mix and inventory planning.

# %% [markdown]
# # Question 8: What is the average customer satisfaction rating of all customers in the dataset?

# %% [markdown]
# ## Business Objective
#
# Management wants to determine the overall average customer satisfaction rating to evaluate the quality of the shopping experience provided by the business.
#
# Monitoring customer satisfaction helps assess overall service quality and provides a baseline for future comparisons across store locations, purchase methods, and customer segments.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$group": {
            "_id": None,
            "average_satisfaction": {
                "$avg": "$customer.satisfaction"
            }
        }
    }
]

result = list(sales.aggregate(pipeline))

average_satisfaction = pd.DataFrame(result)

average_satisfaction
# Out:
#     _id  average_satisfaction
# 0  None                3.7932

# %% [markdown]
# **Extract Average Rating Value**

# %%
avg_rating = average_satisfaction["average_satisfaction"][0]

print("Average Customer Satisfaction Rating:", avg_rating)
# Out:
# Average Customer Satisfaction Rating: 3.7932

# %% [markdown]
# ## Code for Visualization

# %%
plt.figure(figsize=(5,4))

plt.bar(
    ["Average Rating"],
    [avg_rating]
)

plt.ylim(0,5)

plt.title("Average Customer Satisfaction Rating")

plt.ylabel("Rating")

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# The average customer satisfaction rating is 3.79 out of 5, indicating customers are generally satisfied but there is room for improvement.Enhancing service quality and customer experience could further increase satisfaction and customer loyalty.

# %% [markdown]
# # Question 9: Which products have the highest total quantity sold across all sales transactions?

# %% [markdown]
# ## Business Objective
#
# Management wants to identify the products with the highest total quantity sold across all sales transactions.
#
# Since each sales transaction may contain multiple purchased products, the analysis requires examining every product within the `items` array and calculating the total quantity sold for each product. Identifying high-demand products helps the business optimize inventory management, improve procurement planning, and ensure that popular products remain readily available to customers.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$items.name",
            "total_quantity_sold": {
                "$sum": "$items.quantity"
            }
        }
    },
    {
        "$sort": {
            "total_quantity_sold": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

product_quantity = pd.DataFrame(result)

product_quantity
# Out:
#              _id  total_quantity_sold
# 0         binder                25493
# 1      envelopes                25078
# 2        notepad                20727
# 3           pens                13766
# 4  printer paper                12092
# 5       backpack                 6918
# 6         laptop                 6793

# %% [markdown]
# ## Code for Visualization

# %%
top_products = product_quantity.head(10)

plt.figure(figsize=(10,5))

sns.barplot(
    data=top_products,
    x="_id",
    y="total_quantity_sold"
)

plt.title("Top Products by Total Quantity Sold")

plt.xlabel("Product")

plt.ylabel("Total Quantity Sold")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Certain products consistently achieve higher sales volumes, indicating strong customer demand.
# These products serve as key drivers of sales volume and should remain adequately stocked.

# %% [markdown]
# # Question 10: Which products generated the highest total sales revenue across all sales transactions?

# %% [markdown]
# ## Business Objective
#
# Management wants to identify the products that generated the highest total sales revenue.
#
# Unlike the previous analysis, which focused on the quantity sold, this analysis considers both the **selling price** and **quantity sold** to determine the revenue contribution of each product. Understanding product revenue helps the business prioritize high-value products, improve inventory planning, and develop effective sales and marketing strategies.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$items.name",
            "total_revenue": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    },
    {
        "$sort": {
            "total_revenue": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

product_revenue = pd.DataFrame(result)

product_revenue
# Out:
#              _id total_revenue
# 0         laptop    6775977.07
# 1       backpack     817374.10
# 2           pens     581843.27
# 3         binder     511644.57
# 4        notepad     463615.48
# 5      envelopes     376658.49
# 6  printer paper     367459.29

# %%
product_revenue.columns
# Out:
# Index(['_id', 'total_revenue'], dtype='str')

# %%
product_revenue.dtypes
# Out:
# _id                  str
# total_revenue    float64
# dtype: object

# %%
product_revenue.head()
# Out:
#         _id total_revenue
# 0    laptop    6775977.07
# 1  backpack     817374.10
# 2      pens     581843.27
# 3    binder     511644.57
# 4   notepad     463615.48

# %%
from decimal import Decimal

product_revenue["total_revenue"] = product_revenue["total_revenue"].apply(
    lambda x: float(x.to_decimal())
)

# %%
product_revenue["_id"] = product_revenue["_id"].astype(str)

# %% [markdown]
# ## Code for Visualization

# %%
top_revenue_products = product_revenue.head(10)

plt.figure(figsize=(10,5))

sns.barplot(
    data=top_revenue_products,
    x="_id",
    y="total_revenue"
)

plt.title("Top Products by Total Sales Revenue")

plt.xlabel("Product")

plt.ylabel("Total Revenue")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# High-revenue products contribute a significant share of overall sales revenue.Revenue-generating products may differ from high-volume products, highlighting the importance of analyzing both quantity sold and sales value.

# %% [markdown]
# # Question 11: Which store locations generated the highest total sales revenue?

# %% [markdown]
# ## Business Objective
#
# Management wants to compare the sales performance of different store locations based on the total revenue generated.
#
# This analysis calculates the total sales revenue for each store by considering both the selling price and quantity of every product sold. Comparing revenue across store locations helps identify high-performing stores, supports strategic decision-making, and assists in resource allocation, inventory planning, and future business expansion.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$storeLocation",
            "total_revenue": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    },
    {
        "$sort": {
            "total_revenue": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

store_revenue = pd.DataFrame(result)

store_revenue
# Out:
#          _id total_revenue
# 0     Denver    2921009.92
# 1    Seattle    2255947.69
# 2     London    1583066.79
# 3     Austin    1445603.11
# 4   New York    1016059.59
# 5  San Diego     672885.17

# %% [markdown]
# **Convert Decimal128 to Float**

# %%
store_revenue["total_revenue"] = store_revenue["total_revenue"].apply(
    lambda x: float(x.to_decimal())
)

# %%
store_revenue.dtypes
# Out:
# _id                  str
# total_revenue    float64
# dtype: object

# %% [markdown]
# ## Code for Visualization

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=store_revenue,
    x="_id",
    y="total_revenue"
)

plt.title("Total Sales Revenue by Store Location")

plt.xlabel("Store Location")

plt.ylabel("Total Revenue")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Store locations generate different revenue levels, reflecting variations in customer purchasing power and sales performance.High-performing stores can serve as benchmarks for improving other locations.

# %% [markdown]
# # Question 12: How much total sales revenue was generated through each purchase method?

# %% [markdown]
# ## Business Objective
#
# Management wants to compare the revenue generated through different purchase methods, including **In-store**, **Online**, and **Phone** sales.
#
# While previous analyses compared the number of transactions for each purchase method, this analysis focuses on **total sales revenue**. Understanding revenue contribution by purchase channel helps businesses evaluate channel performance, optimize sales strategies, and allocate resources effectively across different customer purchasing channels.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$purchaseMethod",
            "total_revenue": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    },
    {
        "$sort": {
            "total_revenue": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

purchase_revenue = pd.DataFrame(result)

purchase_revenue
# Out:
#         _id total_revenue
# 0  In store    5619138.67
# 1    Online    3163814.67
# 2     Phone    1111618.93

# %% [markdown]
# **Convert Decimal128 to Float**

# %%
purchase_revenue["total_revenue"] = purchase_revenue["total_revenue"].apply(
    lambda x: float(x.to_decimal())
)

# %%
purchase_revenue.dtypes
# Out:
# _id                  str
# total_revenue    float64
# dtype: object

# %% [markdown]
# ## Code for Visualization

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=purchase_revenue,
    x="_id",
    y="total_revenue"
)

plt.title("Total Sales Revenue by Purchase Method")

plt.xlabel("Purchase Method")

plt.ylabel("Total Revenue")

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Revenue contribution differs across purchase methods, demonstrating varying profitability of each sales channel.Understanding channel performance helps optimize resource allocation and customer engagement strategies.

# %% [markdown]
# # Question 13: What is the average transaction value for each store location?

# %% [markdown]
# ## Business Objective
#
# Management wants to compare the **average transaction value** across different store locations.
#
# Since each sales transaction may contain multiple purchased products, the transaction value is calculated by summing the revenue generated from every product within a transaction (Quantity × Price). The average transaction value helps identify stores where customers spend more per purchase, enabling better pricing strategies, promotional planning, customer segmentation, and revenue optimization.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": {
                "transaction_id": "$_id",
                "storeLocation": "$storeLocation"
            },
            "transaction_value": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    },
    {
        "$group": {
            "_id": "$_id.storeLocation",
            "average_transaction_value": {
                "$avg": "$transaction_value"
            }
        }
    },
    {
        "$sort": {
            "average_transaction_value": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

avg_transaction_value = pd.DataFrame(result)

avg_transaction_value
# Out:
#          _id            average_transaction_value
# 0     Austin  2138.466139053254437869822485207101
# 1   New York  2028.063053892215568862275449101796
# 2     London  1993.786889168765743073047858942065
# 3    Seattle  1989.371860670194003527336860670194
# 4  San Diego  1944.754826589595375722543352601156
# 5     Denver  1885.739134925758553905745642349903

# %% [markdown]
# **Convert Decimal128 to Float**

# %%
avg_transaction_value["average_transaction_value"] = avg_transaction_value[
    "average_transaction_value"
].apply(lambda x: float(x.to_decimal()))

# %%
avg_transaction_value.dtypes
# Out:
# _id                              str
# average_transaction_value    float64
# dtype: object

# %% [markdown]
# ## Code for Visualization

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=avg_transaction_value,
    x="_id",
    y="average_transaction_value"
)

plt.title("Average Transaction Value by Store Location")

plt.xlabel("Store Location")

plt.ylabel("Average Transaction Value")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Average transaction values vary between store locations, indicating differences in customer spending patterns.Stores with higher average transaction values demonstrate stronger sales effectiveness or premium customer segments.

# %% [markdown]
# # Question 14: Which products generated the highest sales revenue from transactions where a coupon was used?

# %% [markdown]
# ## Business Objective
#
# Management wants to evaluate the effectiveness of coupon-based sales by identifying the products that generated the highest revenue from transactions where customers used coupons.
#
# This analysis filters only the transactions in which a coupon was applied and calculates the total revenue generated by each product. The results help businesses understand which products perform well during promotional campaigns and support future marketing and discount strategies.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$match": {
            "couponUsed": True
        }
    },
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$items.name",
            "total_revenue": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    },
    {
        "$sort": {
            "total_revenue": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

coupon_product_revenue = pd.DataFrame(result)

coupon_product_revenue
# Out:
#              _id total_revenue
# 0         laptop     663674.10
# 1       backpack      90102.89
# 2           pens      51731.62
# 3         binder      49139.69
# 4        notepad      44703.95
# 5      envelopes      35748.30
# 6  printer paper      35297.13

# %% [markdown]
# **Convert Decimal128 to Float**

# %%
coupon_product_revenue["total_revenue"] = coupon_product_revenue[
    "total_revenue"
].apply(lambda x: float(x.to_decimal()))

# %%
coupon_product_revenue.dtypes
# Out:
# _id                  str
# total_revenue    float64
# dtype: object

# %% [markdown]
# ## Code for Visualization

# %%
top_coupon_products = coupon_product_revenue.head(10)

plt.figure(figsize=(10,5))

sns.barplot(
    data=top_coupon_products,
    x="_id",
    y="total_revenue"
)

plt.title("Top Products by Revenue from Coupon Transactions")

plt.xlabel("Product")

plt.ylabel("Total Revenue")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Coupon-based sales contribute differently across products, showing that promotions are more effective for certain product categories.Strategic coupon campaigns can boost revenue without applying discounts across the entire product range.

# %% [markdown]
# # Question 15: What is the average selling price of each product?

# %% [markdown]
# ## Business Objective
#
# Management wants to determine the average selling price of each product across all sales transactions.
#
# This analysis calculates the average selling price for every product, helping the business understand pricing trends across its product portfolio. The results can support pricing decisions, product positioning, competitor analysis, and future pricing strategies.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$items.name",
            "average_price": {
                "$avg": "$items.price"
            }
        }
    },
    {
        "$sort": {
            "average_price": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

product_average_price = pd.DataFrame(result)

product_average_price
# Out:
#              _id                        average_price
# 0         laptop  992.1520079260237780713342140026420
# 1       backpack  118.4083412732784755305326981377220
# 2           pens  42.23900636104408861592454485632814
# 3  printer paper  30.26948352626892252894033837934105
# 4        notepad  22.42540454016298020954598370197905
# 5         binder  20.02741873396065012831479897348161
# 6      envelopes  15.02021975582685904550499445061043

# %%
product_average_price["average_price"] = product_average_price[
    "average_price"
].apply(lambda x: float(x.to_decimal()))

# %% [markdown]
# ## Code for Visualization

# %%
top_price_products = product_average_price.head(10)

plt.figure(figsize=(10,5))

sns.barplot(
    data=top_price_products,
    x="_id",
    y="average_price"
)

plt.title("Average Selling Price by Product")

plt.xlabel("Product")

plt.ylabel("Average Price")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Average selling prices vary among products, reflecting differences in product positioning and pricing strategies.Price analysis helps identify premium products and supports pricing optimization.

# %% [markdown]
# # Question 16: How can we calculate the total value of each sales transaction using MongoDB Aggregation?

# %% [markdown]
# ## Business Objective
#
# Management wants to determine the monetary value of every sales transaction.
#
# Since each transaction contains multiple purchased products, the total transaction value is calculated by summing the revenue generated by all products in that transaction. This analysis helps identify high-value and low-value purchases, supports customer spending analysis, and forms the foundation for advanced business analytics such as customer segmentation and sales forecasting.
#
# Unlike previous analyses that summarized the entire dataset, this question calculates the value of **every individual transaction**, demonstrating how MongoDB can generate derived business metrics using aggregation pipelines.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$_id",
            "transaction_value": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    },
    {
        "$sort": {
            "transaction_value": -1
        }
    }
]

result = list(sales.aggregate(pipeline))

transaction_values = pd.DataFrame(result)

transaction_values
# Out:
#                            _id transaction_value
# 0     5bd761dcae323e45a93cd1dd           9385.19
# 1     5bd761ddae323e45a93cd537           9105.13
# 2     5bd761deae323e45a93cde98           9005.51
# 3     5bd761ddae323e45a93cd810           8998.43
# 4     5bd761ddae323e45a93cd6fd           8989.94
# ...                        ...               ...
# 4995  5bd761ddae323e45a93cd69b              5.53
# 4996  5bd761deae323e45a93ce021              5.49
# 4997  5bd761ddae323e45a93cd5a1              5.33
# 4998  5bd761ddae323e45a93cd814              5.29
# 4999  5bd761dcae323e45a93cd29a                 5
#
# [5000 rows x 2 columns]

# %%
transaction_values["transaction_value"] = transaction_values[
    "transaction_value"
].apply(lambda x: float(x.to_decimal()))

# %%
transaction_values.head()
# Out:
#                         _id  transaction_value
# 0  5bd761dcae323e45a93cd1dd            9385.19
# 1  5bd761ddae323e45a93cd537            9105.13
# 2  5bd761deae323e45a93cde98            9005.51
# 3  5bd761ddae323e45a93cd810            8998.43
# 4  5bd761ddae323e45a93cd6fd            8989.94

# %% [markdown]
# **Code for Visualization**

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    data=transaction_values,
    x="transaction_value",
    bins=30
)

plt.title("Distribution of Transaction Values")

plt.xlabel("Transaction Value")

plt.ylabel("Number of Transactions")

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Calculating transaction value provides insight into individual customer spending and overall revenue generation.Transaction-level analysis helps identify high-value purchases and customer buying behavior.

# %% [markdown]
# # Question 17: How many sales transactions are classified as High Value and Low Value based on their transaction amount?

# %% [markdown]
# ## Business Objective
#
# Management wants to classify sales transactions into **High Value** and **Low Value** categories based on their total transaction amount.
#
# This analysis first calculates the total value of each transaction and then uses a conditional expression to categorize transactions. Such classifications help businesses identify premium purchases, analyze customer spending behavior, and develop targeted marketing campaigns for different customer segments.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$_id",
            "transaction_value": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    },
    {
        "$project": {
            "transaction_category": {
                "$cond": {
                    "if": {
                        "$gt": [
                            "$transaction_value",
                            1000
                        ]
                    },
                    "then": "High Value",
                    "else": "Low Value"
                }
            }
        }
    },
    {
        "$group": {
            "_id": "$transaction_category",
            "transactions": {
                "$sum": 1
            }
        }
    }
]

result = list(sales.aggregate(pipeline))

transaction_category = pd.DataFrame(result)

transaction_category
# Out:
#           _id  transactions
# 0  High Value          2598
# 1   Low Value          2402

# %% [markdown]
# ## Code for Visualization

# %%
plt.figure(figsize=(7,5))

sns.barplot(
    data=transaction_category,
    x="_id",
    y="transactions"
)

plt.title("High Value vs Low Value Transactions")

plt.xlabel("Transaction Category")

plt.ylabel("Number of Transactions")

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Classifying transactions into high-value and low-value categories helps understand customer spending distribution.High-value transactions contribute significantly to total revenue despite representing a smaller portion of total transactions.

# %% [markdown]
# # Question 18: How are sales transactions distributed across different transaction value ranges?

# %% [markdown]
# ## Business Objective
#
# Management wants to understand how sales transactions are distributed across different transaction value ranges.
#
# Instead of simply classifying transactions as High Value or Low Value, this analysis groups transactions into multiple spending ranges. Understanding the distribution of transaction values helps businesses identify common purchasing patterns, evaluate customer spending behavior, and develop pricing and promotional strategies for different customer segments.

# %% [markdown]
# **Code for Query**

# %%
pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": "$_id",
            "transaction_value": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    },
    {
        "$bucket": {
            "groupBy": "$transaction_value",
            "boundaries": [
                0,
                100,
                500,
                1000,
                5000,
                10000
            ],
            "default": "10000+",
            "output": {
                "transactions": {
                    "$sum": 1
                }
            }
        }
    }
]

result = list(sales.aggregate(pipeline))

transaction_ranges = pd.DataFrame(result)

transaction_ranges
# Out:
#     _id  transactions
# 0     0           322
# 1   100          1213
# 2   500           867
# 3  1000          2036
# 4  5000           562

# %% [markdown]
# ## Code for Visualization

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=transaction_ranges,
    x="_id",
    y="transactions"
)

plt.title("Transaction Distribution by Value Range")

plt.xlabel("Transaction Value Range")

plt.ylabel("Number of Transactions")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# Transaction values are distributed across multiple spending ranges, reflecting different customer purchasing capacities.This distribution supports customer segmentation and targeted marketing strategies.

# %% [markdown]
# # Question 19: How can multiple business summaries be generated simultaneously using MongoDB's `$facet` stage?

# %% [markdown]
# ## Business Objective
#
# Management requires multiple business summaries from the sales dataset, including transaction counts by purchase method, transaction counts by store location, and coupon usage statistics.
#
# Instead of executing separate aggregation queries for each report, MongoDB's **`$facet`** stage allows multiple independent aggregation pipelines to run simultaneously, reducing database queries and improving reporting efficiency.

# %% [markdown]
# ## Code for Query

# %%
pipeline = [
    {
        "$facet": {
            "purchase_method_summary": [
                {
                    "$group": {
                        "_id": "$purchaseMethod",
                        "transactions": {
                            "$sum": 1
                        }
                    }
                },
                {
                    "$sort": {
                        "transactions": -1
                    }
                }
            ],
            
            "store_location_summary": [
                {
                    "$group": {
                        "_id": "$storeLocation",
                        "transactions": {
                            "$sum": 1
                        }
                    }
                },
                {
                    "$sort": {
                        "transactions": -1
                    }
                }
            ],
            
            "coupon_summary": [
                {
                    "$group": {
                        "_id": "$couponUsed",
                        "transactions": {
                            "$sum": 1
                        }
                    }
                }
            ]
        }
    }
]

result = list(sales.aggregate(pipeline))

business_summary = result[0]

business_summary
# Out:
# {'purchase_method_summary': [{'_id': 'In store', 'transactions': 2819},
#   {'_id': 'Online', 'transactions': 1585},
#   {'_id': 'Phone', 'transactions': 596}],
#  'store_location_summary': [{'_id': 'Denver', 'transactions': 1549},
#   {'_id': 'Seattle', 'transactions': 1134},
#   {'_id': 'London', 'transactions': 794},
#   {'_id': 'Austin', 'transactions': 676},
#   {'_id': 'New York', 'transactions': 501},
#   {'_id': 'San Diego', 'transactions': 346}],
#  'coupon_summary': [{'_id': False, 'transactions': 4523},
#   {'_id': True, 'transactions': 477}]}

# %% [markdown]
# **Purchase Method Summary**

# %%
purchase_summary = pd.DataFrame(
    business_summary["purchase_method_summary"]
)

purchase_summary
# Out:
#         _id  transactions
# 0  In store          2819
# 1    Online          1585
# 2     Phone           596

# %% [markdown]
# **Store Location Summary**

# %%
store_summary = pd.DataFrame(
    business_summary["store_location_summary"]
)

store_summary
# Out:
#          _id  transactions
# 0     Denver          1549
# 1    Seattle          1134
# 2     London           794
# 3     Austin           676
# 4   New York           501
# 5  San Diego           346

# %% [markdown]
# **Coupon Summary**

# %%
coupon_summary = pd.DataFrame(
    business_summary["coupon_summary"]
)

coupon_summary
# Out:
#      _id  transactions
# 0  False          4523
# 1   True           477

# %% [markdown]
# **Code for Visualization
# Purchase Method Distribution**

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=purchase_summary,
    x="_id",
    y="transactions"
)

plt.title("Transactions by Purchase Method")

plt.xlabel("Purchase Method")

plt.ylabel("Transactions")

plt.show()

# %% [markdown]
# **Store Location Distribution**

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=store_summary,
    x="_id",
    y="transactions"
)

plt.title("Transactions by Store Location")

plt.xlabel("Store Location")

plt.ylabel("Transactions")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# The $facet operation enables simultaneous generation of purchase method, store location, and coupon summaries.Combining multiple business metrics into a single analysis improves reporting efficiency and supports faster managerial decision-making.

# %% [markdown]
# # Question 20: How can an Executive Business Dashboard be created using MongoDB Aggregation and Python?

# %% [markdown]
# ## Business Objective
#
# Senior management requires an Executive Business Dashboard that provides a quick overview of the organization's overall sales performance.
#
# Instead of examining individual reports separately, businesses often consolidate multiple Key Performance Indicators (KPIs) and visualizations into a single dashboard. Such dashboards enable executives to monitor business performance, identify trends, and make informed strategic decisions.
#
# The dashboard summarizes the following business metrics:
#
# - Total Sales Transactions
# - Total Sales Revenue
# - Average Customer Satisfaction
# - Store Performance
# - Purchase Method Distribution
# - Coupon Usage Distribution
#
# This dashboard combines the analytical results obtained throughout the case study into a single visual report.

# %% [markdown]
# ## Code for Executive Business Dashboard

# %%
purchase_pipeline = [
    {
        "$group": {
            "_id": "$purchaseMethod",
            "transactions": {
                "$sum": 1
            }
        }
    },
    {
        "$sort": {
            "transactions": -1
        }
    }
]

purchase_result = list(sales.aggregate(purchase_pipeline))

purchase_transactions = pd.DataFrame(purchase_result)

purchase_transactions
# Out:
#         _id  transactions
# 0  In store          2819
# 1    Online          1585
# 2     Phone           596

# %%
rating_pipeline = [
    {
        "$group": {
            "_id": None,
            "average_rating": {
                "$avg": "$customer.satisfaction"
            }
        }
    }
]

result = list(sales.aggregate(rating_pipeline))

average_rating = result[0]["average_rating"]

average_rating
# Out:
# 3.7932

# %%
total_revenue_pipeline = [
    {
        "$unwind": "$items"
    },
    {
        "$group": {
            "_id": None,
            "total_revenue": {
                "$sum": {
                    "$multiply": [
                        "$items.quantity",
                        "$items.price"
                    ]
                }
            }
        }
    }
]

result = list(sales.aggregate(total_revenue_pipeline))

total_revenue = float(
    result[0]["total_revenue"].to_decimal()
)

total_revenue
# Out:
# 9894572.27

# %%
print("Executive Business Dashboard")
print("--------------------------------")

print("Total Sales Transactions :", total_transactions)

print("Total Sales Revenue      :", round(total_revenue, 2))

print("Average Customer Rating  :", round(average_rating, 2))
# Out:
# Executive Business Dashboard
# --------------------------------
# Total Sales Transactions : 5000
# Total Sales Revenue      : 9894572.27
# Average Customer Rating  : 3.79

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))


# 1. Store Performance
sns.barplot(
    data=store_revenue,
    x="_id",
    y="total_revenue",
    ax=axes[0]
)

axes[0].set_title("Revenue by Store Location")
axes[0].set_xlabel("Store Location")
axes[0].set_ylabel("Revenue")
axes[0].tick_params(axis="x", rotation=45)


# 2. Purchase Method Distribution
sns.barplot(
    data=purchase_transactions,
    x="_id",
    y="transactions",
    ax=axes[1]
)

axes[1].set_title("Transactions by Purchase Method")
axes[1].set_xlabel("Purchase Method")
axes[1].set_ylabel("Transactions")


# 3. Coupon Usage Distribution
sns.barplot(
    data=coupon_summary,
    x="_id",
    y="transactions",
    ax=axes[2]
)

axes[2].set_title("Coupon Usage Distribution")
axes[2].set_xlabel("Coupon Used")
axes[2].set_ylabel("Transactions")


plt.tight_layout()

plt.show()

# %% [markdown]
# **Business Insights:**

# %% [markdown]
# The executive dashboard provides a consolidated view of key business KPIs, including 5,000 total transactions, total sales revenue of approximately 9.89 million, and an average customer rating of 3.79.Integrating multiple performance metrics into a single dashboard enables management to monitor business health, identify trends, and make informed strategic decisions more efficiently.

# %% [markdown]
# ## Overall Business Insights
#
# * The business generated strong sales performance with **5,000 transactions** and approximately **₹9.89 million in total revenue**, indicating consistent customer demand across products, stores, and purchase channels.
# * Sales and revenue vary across **store locations, purchase methods, and products**, highlighting opportunities to optimize business operations and focus on high-performing areas.
# * Customer satisfaction remains positive, while seasonal sales trends and coupon usage influence purchasing behavior, emphasizing the importance of data-driven decision-making.
#
# ## Business Actions
#
# * Focus on improving underperforming stores, products, and sales channels while strengthening the performance of high-performing ones.
# * Continuously monitor key business KPIs such as revenue, transactions, customer satisfaction, and average transaction value using business dashboards.
# * Optimize inventory management and promotional campaigns based on product demand, seasonal trends, and customer purchasing patterns.
#
# ## Business Recommendations
#
# * Invest more in high-performing products, store locations, and purchase channels to maximize revenue and support long-term business growth.
# * Improve customer satisfaction and retention through personalized marketing, loyalty programs, and enhanced customer service.
# * Leverage business intelligence tools and predictive analytics to forecast demand, support strategic planning, and enable data-driven decision-making.
